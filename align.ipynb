# %%
from piron import FitsArray

# %%
fa = FitsArray.from_pattern("data/cali/*.fit")
fa
# Out:
# FitsArray(@: 139806919091216, nof: 510)

# %%
aligned = fa.align(fa[0], output="data/ali")
aligned
# Out:
# FitsArray(@: 139806296803168, nof: 499)

# %%
aligned[0].show()

# %%
aligned[100].show()
